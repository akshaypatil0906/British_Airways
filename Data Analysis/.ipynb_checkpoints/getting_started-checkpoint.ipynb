# %% [markdown]
# # Task 1
#
# ---
#
# ## Web scraping and analysis
#
# This Jupyter notebook includes some code to get you started with web scraping. We will use a package called `BeautifulSoup` to collect the data from the web. Once you've collected your data and saved it into a local `.csv` file you should start with your analysis.
#
# ### Scraping data from Skytrax
#
# If you visit [https://www.airlinequality.com] you can see that there is a lot of data there. For this task, we are only interested in reviews related to British Airways and the Airline itself.
#
# If you navigate to this link: [https://www.airlinequality.com/airline-reviews/british-airways] you will see this data. Now, we can use `Python` and `BeautifulSoup` to collect all the links to the reviews and then to collect the text data on each of the individual review links.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np

# %%
base_url = "https://www.airlinequality.com/airline-reviews/british-airways"
pages = 10
page_size = 100

reviews = []

# for i in range(1, pages + 1):
for i in range(1, pages + 1):

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text())
    
    print(f"   ---> {len(reviews)} total reviews")
# Out:
# Scraping page 1
#    ---> 100 total reviews
# Scraping page 2
#    ---> 200 total reviews
# Scraping page 3
#    ---> 300 total reviews
# Scraping page 4
#    ---> 400 total reviews
# Scraping page 5
#    ---> 500 total reviews
# Scraping page 6
#    ---> 600 total reviews
# Scraping page 7
#    ---> 700 total reviews
# Scraping page 8
#    ---> 800 total reviews
# Scraping page 9
#    ---> 900 total reviews
# Scraping page 10
#    ---> 1000 total reviews

# %%
df = pd.DataFrame()
df["reviews"] = reviews
df.head()
# Out:
#                                              reviews
# 0  ✅ Trip Verified |  British Airways is late, th...
# 1  ✅ Trip Verified | Flew from Amman to London on...
# 2  ✅ Trip Verified | This is the worst experience...
# 3  ✅ Trip Verified |  Flying LHR T5 to CPT Novemb...
# 4  Not Verified | Worst experience ever. Outbound...

# %%
df.to_csv(f"BA_reviews.csv")

# %% [markdown]
# Congratulations! Now you have your dataset for this task! The loops above collected 1000 reviews by iterating through the paginated pages on the website. However, if you want to collect more data, try increasing the number of pages!
#
#  The next thing that you should do is clean this data to remove any unnecessary text from each of the rows. For example, "✅ Trip Verified" can be removed from each row if it exists, as it's not relevant to what we want to investigate.

# %%
df["reviews"] =[x.strip("✅ Trip Verified |") for x in df["reviews"]]

# %%
df["reviews"] =[x.strip("Not Verified | ") for x in df["reviews"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 1 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   reviews  1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#                                                   reviews
# count                                                1000
# unique                                               1000
# top     British Airways is late, their website is atro...
# freq                                                    1

# %%
df["reviews"][0]
# Out:
# "British Airways is late, their website is atrocious, and they wouldn't let me check-in until 24 hours before the flight. I have been trying for 6 hours to check in through their website, and/or find a real person to speak with. Customer service had such a thick accent I didn't think they were speaking English."

# %%
#created Fn for Lowercasing Everything
def lowerc(txt):
    return txt.lower()

# %%
#converting to lowercase
df["reviews"] = df["reviews"].apply(lowerc)

# %%
#fn to remove Special char
def remove_s(txt):
    x =" "
    for i in txt:
        if i.isalpha():
            x =x+i
        else:
            x=x+" "
    return x

# %%
#remove special chars
df["reviews"] = df["reviews"].apply(remove_s)

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\ugc\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#remove stopwords
from nltk.corpus import stopwords
stopwords.words("english")
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
#fn to remove stopwords
def remove_sw(txt):
    x=[]
    for i in txt.split():
        if i not in stopwords.words("english"):
            x.append(i)
    y=x[:]
    x.clear()
    return y

# %%
#remove special chars
df["reviews"] = df["reviews"].apply(remove_sw)

# %%
#stemming
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
y =[]
def stem_words(txt):
    for i in txt:
        y.append(ps.stem(i))
    z=y[:]
    y.clear()
    return z

# %%
df["reviews"] = df["reviews"].apply(stem_words)

# %%
df
# Out:
#                                                reviews
# 0    [british, airways, late, website, atrocious, l...
# 1    [flew, amman, london, nov, sure, type, aircraf...
# 2    [worst, experience, ever, airline, flew, briti...
# 3    [flying, lhr, cpt, november, ba, app, website,...
# 4    [worst, experience, ever, outbound, flight, ca...
# ..                                                 ...
# 995  [full, flight, g, bnlp, b, flying, miami, lond...
# 996  [warsaw, london, waw, pleasant, airport, one, ...
# 997  [booked, flight, cathay, pacific, route, stock...
# 998  [flew, british, airways, lisbon, london, heath...
# 999  [singapore, heathrow, skipped, meal, board, re...
#
# [1000 rows x 1 columns]

# %%
df1 = df["reviews"]

# %%
#joining list to string
def joinl(input_l):
    return " ".join(input_l)

# %%
df["reviews"] = df["reviews"].apply(joinl)

# %%
df

# %%
#converting to vectors
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer()

# %%
x = cv.fit_transform(df["reviews"]).toarray()

# %%
x.shape
# Out:
# (1000, 7054)

# %%
pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

# iterate through the csv file
for val in df["reviews"]:
    val = str(val)
    
wordcloud1 = WordCloud(width = 800, height = 800,
                background_color ='white',
                min_font_size = 10).generate(val)
 
# plot the WordCloud image                      
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud1)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.savefig("BA.png") 
plt.show()

# %%
t =[]
import seaborn as sns
from nltk.probability import FreqDist
for i in df["reviews"]:
    for j in i:
        tokens = nltk.word_tokenize(j)
        t.append(tokens)
t2 = FreqDist(t)  
plt.figure(figsize=(12,4))
t2.plot()
sns.countplot(x=t2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [101], in <cell line: 8>()
#       6         tokens = nltk.word_tokenize(j)
#       7         t.append(tokens)
# ----> 8 t2 = FreqDist(t)
#       9 plt.figure(figsize=(12,4))
#      10 t2.plot()
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\probability.py:102, in FreqDist.__init__(self, samples)
#      86 def __init__(self, samples=None):
#      87     """
#      88     Construct a new frequency distribution.  If ``samples`` is
#      89     given, then the frequency distribution will be initialized
#    (...)
#     100     :type samples: Sequence
#     101     """
# --> 102     Counter.__init__(self, samples)
#     104     # Cached number of samples in this FreqDist
#     105     self._N = None
#
# File c:\users\ugc\miniconda3\lib\collections\__init__.py:552, in Counter.__init__(self, iterable, **kwds)
#     541 '''Create a new, empty Counter object.  And if given, count elements
#     542 from an input iterable.  Or, initialize the count from another mapping
#     543 of elements to their counts.
#    (...)
#     549
#     550 '''
#     551 super(Counter, self).__init__()
# --> 552 self.update(iterable, **kwds)
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\probability.py:140, in FreqDist.update(self, *args, **kwargs)
#     136 """
#     137 Override ``Counter.update()`` to invalidate the cached N
#     138 """
#     139 self._N = None
# --> 140 super().update(*args, **kwargs)
#
# File c:\users\ugc\miniconda3\lib\collections\__init__.py:637, in Counter.update(self, iterable, **kwds)
#     635             super(Counter, self).update(iterable) # fast path when counter is empty
#     636     else:
# --> 637         _count_elements(self, iterable)
#     638 if kwds:
#     639     self.update(kwds)
#
# TypeError: unhashable type: 'list'

# %%
n = nltk.word_tokenize(df1)
n
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [90], in <cell line: 1>()
# ----> 1 n = nltk.word_tokenize(df1)
#       2 n
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\tokenize\__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\tokenize\__init__.py:107, in sent_tokenize(text, language)
#      97 """
#      98 Return a sentence-tokenized copy of *text*,
#      99 using NLTK's recommended sentence tokenizer
#    (...)
#     104 :param language: the model name in the Punkt corpus
#     105 """
#     106 tokenizer = load(f"tokenizers/punkt/{language}.pickle")
# --> 107 return tokenizer.tokenize(text)
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\tokenize\punkt.py:1276, in PunktSentenceTokenizer.tokenize(self, text, realign_boundaries)
#    1272 def tokenize(self, text, realign_boundaries=True):
#    1273     """
#    1274     Given a text, returns a list of the sentences in that text.
#    1275     """
# -> 1276     return list(self.sentences_from_text(text, realign_boundaries))
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\tokenize\punkt.py:1332, in PunktSentenceTokenizer.sentences_from_text(self, text, realign_boundaries)
#    1325 def sentences_from_text(self, text, realign_boundaries=True):
#    1326     """
#    1327     Given a text, generates the sentences in that text by only
#    1328     testing candidate sentence breaks. If realign_boundaries is
#    1329     True, includes in the sentence closing punctuation that
#    1330     follows the period.
#    1331     """
# -> 1332     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\tokenize\punkt.py:1332, in <listcomp>(.0)
#    1325 def sentences_from_text(self, text, realign_boundaries=True):
#    1326     """
#    1327     Given a text, generates the sentences in that text by only
#    1328     testing candidate sentence breaks. If realign_boundaries is
#    1329     True, includes in the sentence closing punctuation that
#    1330     follows the period.
#    1331     """
# -> 1332     return [text[s:e] for s, e in self.span_tokenize(text, realign_boundaries)]
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\tokenize\punkt.py:1322, in PunktSentenceTokenizer.span_tokenize(self, text, realign_boundaries)
#    1320 if realign_boundaries:
#    1321     slices = self._realign_boundaries(text, slices)
# -> 1322 for sentence in slices:
#    1323     yield (sentence.start, sentence.stop)
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\tokenize\punkt.py:1421, in PunktSentenceTokenizer._realign_boundaries(self, text, slices)
#    1408 """
#    1409 Attempts to realign punctuation that falls after the period but
#    1410 should otherwise be included in the same sentence.
#    (...)
#    1418     ["(Sent1.)", "Sent2."].
#    1419 """
#    1420 realign = 0
# -> 1421 for sentence1, sentence2 in _pair_iter(slices):
#    1422     sentence1 = slice(sentence1.start + realign, sentence1.stop)
#    1423     if not sentence2:
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\tokenize\punkt.py:318, in _pair_iter(iterator)
#     316 iterator = iter(iterator)
#     317 try:
# --> 318     prev = next(iterator)
#     319 except StopIteration:
#     320     return
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\tokenize\punkt.py:1395, in PunktSentenceTokenizer._slices_from_text(self, text)
#    1393 def _slices_from_text(self, text):
#    1394     last_break = 0
# -> 1395     for match, context in self._match_potential_end_contexts(text):
#    1396         if self.text_contains_sentbreak(context):
#    1397             yield slice(last_break, match.end())
#
# File c:\users\ugc\miniconda3\lib\site-packages\nltk\tokenize\punkt.py:1375, in PunktSentenceTokenizer._match_potential_end_contexts(self, text)
#    1373 before_words = {}
#    1374 matches = []
# -> 1375 for match in reversed(list(self._lang_vars.period_context_re().finditer(text))):
#    1376     # Ignore matches that have already been captured by matches to the right of this match
#    1377     if matches and match.end() > before_start:
#    1378         continue
#
# TypeError: expected string or bytes-like object
